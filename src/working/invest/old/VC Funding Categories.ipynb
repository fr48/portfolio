# %% [markdown]
# # Who Is Investing in CyberSecurity?
#
# Cybersecurity is red-hot and there is a lot of money being thrown at the industry. Where is the bulk of the money going?
#
# ### Data Sources
#
# * Crunchbase
#
#     - investment-2017 in investment-2019.csv
#
#     - investment-XXX.csv {security, cybersecurity, cloud security, network security, privacy, blockchain, (bitcoin, ethereum, cryptocurrency), identity management, compliance}
#
#
# * CyberSecurityVenures
#
# ### Ideas
#
# * Is it worth seeing where the different investments are for each category?
#
# * Who are the ones investing in security?

# %%
import requests
import re
import pandas as pd
import numpy as np

import datetime

pd.set_option('display.max_columns', 500)

import statsmodels.api as sm
from statsmodels.sandbox.regression.predstd import wls_prediction_std

import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %% [markdown]
# ## Prepare the individual data sets
#
# by security category

# %%
privacy = pd.read_csv('investment-privacy.csv')
privacy['category'] = "Privacy"
privacy.shape
# Out:
# (88, 21)

# %%
privacy = privacy.drop(['Founded Date','Organization Name URL','Exit Date','Founded Date Precision','Exit Date Precision','Last Funding Amount Currency','Last Funding Amount','Last Equity Funding Amount', 'Last Equity Funding Amount Currency',"Headquarters Location","Headquarters Regions","Last Equity Funding Amount Currency (in USD)"], axis=1)

#rename fields for easier access
privacy = privacy.rename(columns={"Organization Name": "Organization", 
                   "Last Funding Date" : "Privacy_Date",
                   "Last Funding Amount Currency (in USD)" : "Privacy_Amount",
                   "Last Funding Type" : "Privacy_Type",
                   "Funding Status" : "Privacy_Status",
                   "Top 5 Investors" : "Privacy_Top5",
                   "Number of Investors" : "Privacy_Investors",
                   "category" : "Privacy"
                  })
privacy = privacy.set_index('Organization')
privacy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 88 entries, OneTrust to @unik-name
# Data columns (total 8 columns):
# Categories           88 non-null object
# Privacy_Date         88 non-null object
# Privacy_Amount       61 non-null float64
# Privacy_Type         88 non-null object
# Privacy_Status       71 non-null object
# Privacy_Top5         76 non-null object
# Privacy_Investors    76 non-null float64
# Privacy              88 non-null object
# dtypes: float64(2), object(6)
# memory usage: 6.2+ KB

# %%
cloud = pd.read_csv('investment-cloud.csv')
cloud['category'] = "Cloud"
cloud.shape
# Out:
# (129, 21)

# %%
cloud = cloud.drop(['Founded Date','Organization Name URL','Exit Date','Founded Date Precision','Exit Date Precision','Last Funding Amount Currency','Last Funding Amount','Last Equity Funding Amount', 'Last Equity Funding Amount Currency',"Headquarters Location","Headquarters Regions","Last Equity Funding Amount Currency (in USD)"], axis=1)

#rename fields for easier access
cloud = cloud.rename(columns={"Organization Name": "Organization", 
                   "Last Funding Date" : "Cloud_Date",
                   "Last Funding Amount Currency (in USD)" : "Cloud_Amount",
                   "Last Funding Type" : "Cloud_Type",
                   "Funding Status" : "Cloud_Status",
                   "Top 5 Investors" : "Cloud_Top5",
                   "Number of Investors" : "Cloud_Investors",
                   "category" : "Cloud"
                  })
cloud = cloud.set_index('Organization')
cloud.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129 entries, Netskope to APIIDA
# Data columns (total 8 columns):
# Categories         129 non-null object
# Cloud_Date         129 non-null object
# Cloud_Amount       104 non-null float64
# Cloud_Type         129 non-null object
# Cloud_Status       111 non-null object
# Cloud_Top5         115 non-null object
# Cloud_Investors    115 non-null float64
# Cloud              129 non-null object
# dtypes: float64(2), object(6)
# memory usage: 9.1+ KB

# %%
compliance = pd.read_csv('investment-compliance.csv')
compliance['category'] = "Compliance"
compliance.shape
# Out:
# (132, 21)

# %%
compliance = compliance.drop(['Founded Date','Organization Name URL','Exit Date','Founded Date Precision','Exit Date Precision','Last Funding Amount Currency','Last Funding Amount','Last Equity Funding Amount', 'Last Equity Funding Amount Currency',"Headquarters Location","Headquarters Regions","Last Equity Funding Amount Currency (in USD)"], axis=1)

#rename fields for easier access
compliance = compliance.rename(columns={"Organization Name": "Organization", 
                   "Last Funding Date" : "Compliance_Date",
                   "Last Funding Amount Currency (in USD)" : "Compliance_Amount",
                   "Last Funding Type" : "Compliance_Type",
                   "Funding Status" : "Compliance_Status",
                   "Top 5 Investors" : "Compliance_Top5",
                   "Number of Investors" : "Compliance_Investors",
                   "category" : "Compliance"
                  })
compliance = compliance.set_index('Organization')

# %%
identity = pd.read_csv('investment-identity.csv')
identity['category'] = "Identity"
identity.shape
# Out:
# (134, 21)

# %%
identity = identity.drop(['Founded Date','Organization Name URL','Exit Date','Founded Date Precision','Exit Date Precision','Last Funding Amount Currency','Last Funding Amount','Last Equity Funding Amount', 'Last Equity Funding Amount Currency',"Headquarters Location","Headquarters Regions","Last Equity Funding Amount Currency (in USD)"], axis=1)

#rename fields for easier access
identity = identity.rename(columns={"Organization Name": "Organization", 
                   "Last Funding Date" : "Identity_Date",
                   "Last Funding Amount Currency (in USD)" : "Identity_Amount",
                   "Last Funding Type" : "Identity_Type",
                   "Funding Status" : "Identity_Status",
                   "Top 5 Investors" : "Identity_Top5",
                   "Number of Investors" : "Identity_Investors",
                   "category" : "Identity"
                  })
identity = identity.set_index('Organization')

# %%
network = pd.read_csv('investment-network.csv')
network['category'] = "Network"
network.shape
# Out:
# (333, 21)

# %%
network = network.drop(['Founded Date','Organization Name URL','Exit Date','Founded Date Precision','Exit Date Precision','Last Funding Amount Currency','Last Funding Amount','Last Equity Funding Amount', 'Last Equity Funding Amount Currency',"Headquarters Location","Headquarters Regions","Last Equity Funding Amount Currency (in USD)"], axis=1)

#rename fields for easier access
network = network.rename(columns={"Organization Name": "Organization", 
                   "Last Funding Date" : "Network_Date",
                   "Last Funding Amount Currency (in USD)" : "Network_Amount",
                   "Last Funding Type" : "Network_Type",
                   "Funding Status" : "Network_Status",
                   "Top 5 Investors" : "Network_Top5",
                   "Number of Investors" : "Network_Investors",
                   "category" : "Network"
                  })
network = network.set_index('Organization')

# %%
cybersecurity = pd.read_csv('investment-cybersecurity.csv')
cybersecurity['category'] = "Cybersecurity"
cybersecurity.shape
# Out:
# (704, 21)

# %%
cybersecurity = cybersecurity.drop(['Founded Date','Organization Name URL','Exit Date','Founded Date Precision','Exit Date Precision','Last Funding Amount Currency','Last Funding Amount','Last Equity Funding Amount', 'Last Equity Funding Amount Currency',"Headquarters Location","Headquarters Regions","Last Equity Funding Amount Currency (in USD)"], axis=1)

#rename fields for easier access
cybersecurity = cybersecurity.rename(columns={"Organization Name": "Organization", 
                   "Last Funding Date" : "cybersecurity_Date",
                   "Last Funding Amount Currency (in USD)" : "cybersecurity_Amount",
                   "Last Funding Type" : "cybersecurity_Type",
                   "Funding Status" : "cybersecurity_Status",
                   "Top 5 Investors" : "cybersecurity_Top5",
                   "Number of Investors" : "cybersecurity_Investors",
                   "category" : "cybersecurity"
                  })
cybersecurity = cybersecurity.set_index('Organization')

# %%
security = pd.read_csv('investment-security.csv')
security['category'] = "Security"
security.shape
# Out:
# (800, 21)

# %%
security = security.drop(['Founded Date','Organization Name URL','Exit Date','Founded Date Precision','Exit Date Precision','Last Funding Amount Currency','Last Funding Amount','Last Equity Funding Amount', 'Last Equity Funding Amount Currency',"Headquarters Location","Headquarters Regions","Last Equity Funding Amount Currency (in USD)"], axis=1)

#rename fields for easier access
security = security.rename(columns={"Organization Name": "Organization", 
                   "Last Funding Date" : "security_Date",
                   "Last Funding Amount Currency (in USD)" : "security_Amount",
                   "Last Funding Type" : "security_Type",
                   "Funding Status" : "security_Status",
                   "Top 5 Investors" : "security_Top5",
                   "Number of Investors" : "security_Investors",
                   "category" : "security"
                  })
security = security.set_index('Organization')

# %%
result = pd.concat([cloud, security], axis=1, sort=False)
result[(result.Cloud_Amount > 0) & (result.Security_Amount >0)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-171-a08abd6c0d3b> in <module>
# ----> 1 result = pd.concat([cloud, security], axis=1, sort=False)
#       2 result[(result.Cloud_Amount > 0) & (result.Security_Amount >0)]
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     227                        verify_integrity=verify_integrity,
#     228                        copy=copy, sort=sort)
# --> 229     return op.get_result()
#     230
#     231
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     424             new_data = concatenate_block_managers(
#     425                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 426                 copy=self.copy)
# ...

# %%
#combine to a wide table
result = pd.concat([compliance, privacy, identity, cloud, network, security, cybersecurity], axis=1, sort=False)
result.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-163-9ae46f452163> in <module>
#       1 #combine to a wide table
# ----> 2 result = pd.concat([security, cybersecurity], axis=1, sort=False)
#       3 result.shape
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     227                        verify_integrity=verify_integrity,
#     228                        copy=copy, sort=sort)
# --> 229     return op.get_result()
#     230
#     231
#
# ~/.local/lib/python3.7/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     424             new_data = concatenate_block_managers(
#     425                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 426                 copy=self.copy)
# ...

# %%
blockchain = pd.read_csv('investment-blockchain.csv')
blockchain['category'] = "Blockchain"
blockchain.shape
# Out:
# (946, 21)

# %%
cryptocurrency = pd.read_csv('investment-cryptocurrency.csv')
cryptocurrency['category'] = "Cryptocurrency"
cryptocurrency.shape
# Out:
# (791, 21)

# %%
#Year.value_counts().plot(kind="barh", figsize=(20,10))
#plt.savefig("data/breaches_year.pdf", transparent=True)
# Out:
# Organization Name                                 0
# Organization Name URL                             0
# Categories                                        0
# Headquarters Location                             4
# Headquarters Regions                            111
# Founded Date                                     79
# Founded Date Precision                           79
# Exit Date                                       747
# Exit Date Precision                             747
# Last Funding Date                                 0
# Last Funding Amount                             199
# Last Funding Amount Currency                    199
# Last Funding Amount Currency (in USD)           199
# Last Funding Type                                 0
# Last Equity Funding Amount                      220
# Last Equity Funding Amount Currency             220
# Last Equity Funding Amount Currency (in USD)    220
# Funding Status                                  194
# ...

# %% [markdown]
# ### Cleanup and format each table

# %%
all_data['Last Funding Date'] = pd.to_datetime(all_data['Last Funding Date'])
all_data['Period']=pd.to_datetime(all_data['Last Funding Date']).dt.to_period('M')
all_data['Quarter']=all_data['Period'].astype(str)
all_data.Quarter.replace(['2019-01', '2019-02', '2019-03'], '20191Q', inplace=True)
all_data.Quarter.replace(['2019-04', '2019-05', '2019-06'], '20192Q', inplace=True)
all_data.Quarter.replace(['2019-07', '2019-08', '2019-09'], '20193Q', inplace=True)
all_data.Quarter.replace(['2018-01', '2018-02', '2018-03'], '20181Q', inplace=True)
all_data.Quarter.replace(['2018-04', '2018-05', '2018-06'], '20182Q', inplace=True)
all_data.Quarter.replace(['2018-07', '2018-08', '2018-09'], '20183Q', inplace=True)
all_data.Quarter.replace(['2018-10', '2018-11', '2018-12'], '20184Q', inplace=True)
all_data.Quarter.replace(['2017-07', '2017-08', '2017-09'], '20173Q', inplace=True)
all_data.Quarter.replace(['2017-10', '2017-11', '2017-12'], '20174Q', inplace=True)

all_data = all_data.drop(['Founded Date','Organization Name URL','Exit Date', 'Founded Date','Founded Date Precision','Exit Date Precision','Last Funding Amount Currency','Last Funding Amount','Last Equity Funding Amount', 'Last Equity Funding Amount Currency'], axis=1)
all_data.head(10)
# Out:
#           Organization Name  \
# 0           Recorded Future
# 1              Binance Labs
# 2                   Zscaler
# 3               Bitdefender
# 4              Duo Security
# 5  Tenable Network Security
# 6                 ForgeRock
# 7              Threat Stack
# 8           Skybox Security
# 9                     Huobi
#
#                                           Categories  \
# 0  Analytics, Cyber Security, Machine Learning, R...
# 1                           Cryptocurrency, Ethereum
# 2  Cloud Security, Cyber Security, Enterprise Sof...
# 3  Cloud Security, Cyber Security, Network Securi...
# 4  Cloud Security, Cyber Security, Enterprise Sof...
# 5  Compliance, Network Security, Risk Management,...
# 6  Cyber Security, Enterprise Software, Identity ...
# 7                     Cloud Security, SaaS, Security
# 8  Cloud Security, Cyber Security, Enterprise Sof...
# 9       Bitcoin, Blockchain, Cryptocurrency, FinTech
#
#                       Headquarters Location  \
# ...

# %%
#rename fields for easier access
all_data = all_data.rename(columns={"Organization Name": "Organization", 
                   "Headquarters Location": "Location",
                   "Headquarters Regions" : "Region",
                   "Last Funding Date" : "FundingDate",
                   "Last Funding Amount Currency (in USD)" : "FundingAmount",
                   "Last Funding Type" : "FundingType",
                   "Last Equity Funding Amount Currency (in USD)" : "EquityAmount",
                   "Funding Status" : "Status",
                   "Top 5 Investors" : "Top5",
                   "Number of Investors" : "Investors"
                  })
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3209 entries, 0 to 788
# Data columns (total 15 columns):
# Organization     3209 non-null object
# Categories       3209 non-null object
# Location         3131 non-null object
# Region           2695 non-null object
# ExitDate         109 non-null datetime64[ns]
# FundingDate      3209 non-null datetime64[ns]
# FundingAmount    2212 non-null float64
# FundingType      3209 non-null object
# EquityAmount     2137 non-null float64
# Status           2268 non-null object
# Top5             2487 non-null object
# Investors        2487 non-null float64
# Founded          2830 non-null float64
# Period           3209 non-null period[M]
# Quarter          3209 non-null object
# dtypes: datetime64[ns](2), float64(4), object(8), period[M](1)
# memory usage: 401.1+ KB

# %%
#understanding the data
all_data.isnull().sum()
# Out:
# Organization        0
# Categories          0
# Location           78
# Region            514
# ExitDate         3100
# FundingDate         0
# FundingAmount     997
# FundingType         0
# EquityAmount     1072
# Status            941
# Top5              722
# Investors         722
# Founded           379
# Period              0
# Quarter             0
# dtype: int64

# %% [markdown]
# ### Editorial Decision
# In a research about investments, there's no value in keeping the private investments or other undisclosed rounds. Dropping rows that have no funding amount. Some had an exit (ipo, m&a, etc), some are undisclosed, and some have weird exit dates

# %%
all_data = all_data.dropna(subset=['FundingAmount'])
all_data.shape
# Out:
# (2212, 15)

# %%
all_data.isnull().sum()
# Out:
# Organization        0
# Categories          0
# Location           37
# Region            371
# ExitDate         2139
# FundingDate         0
# FundingAmount       0
# FundingType         0
# EquityAmount      104
# Status            616
# Top5              510
# Investors         510
# Founded           214
# Period              0
# Quarter             0
# dtype: int64

# %% [markdown]
# ### Format the investors and region fields

# %%
all_data["Invest"]= all_data["Top5"].str.split(",", n = -1) 
all_data.head(5)
# Out:
# /home/fahmida/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                 Organization  \
# 0            Recorded Future
# 3                Bitdefender
# 4               Duo Security
# 6                  ForgeRock
# 7               Threat Stack
# 8            Skybox Security
# 9                      Huobi
# 12  Bitwise Asset Management
# 14                   Instart
# 15                  Lastline
# 16                   Intezer
# 18                Flashpoint
# 19              IdentityMind
# 20                    Airfox
# 21                  Mimecast
# 23                SecureAuth
# 24                  Callsign
# 25                   ZingBox
# ...

# %%
tags = all_data.Invest.apply(pd.Series)
tags = tags.drop(5, axis=1)
tags = tags.rename(columns = lambda x : 'investor_' + str(x+1))
tags.head(5)
# Out:
#               investor_1                          investor_2  \
# 0      Balderton Capital                                  GV
# 3  Balkan Accession Fund   Romanian-American Enterprise Fund
# 4                     GV                      Index Ventures
# 6                  Accel                  Foundation Capital
# 7          Atlas Venture                Eight Roads Ventures
#
#                        investor_3                  investor_4  \
# 0                     IA Ventures            Insight Partners
# 3              Vitruvian Partners                         NaN
# 4                        Redpoint               True Ventures
# 6         Kohlberg Kravis Roberts   Meritech Capital Partners
# 7   Right Side Capital Management      Scale Venture Partners
#
#              investor_5
# 0   MassMutual Ventures
# 3                   NaN
# 4               Workday
# 6                   NaN
# 7             Techstars

# %%
my_data = pd.concat([all_data[:], tags[:]], axis=1)
all_data = my_data
all_data.shape
# Out:
# (2212, 21)

# %%
all_data["Place"]= all_data["Region"].str.split(",", n = -1) 
all_data.head(5)
# Out:
#       Organization                                         Categories  \
# 0  Recorded Future  Analytics, Cyber Security, Machine Learning, R...
# 3      Bitdefender  Cloud Security, Cyber Security, Network Securi...
# 4     Duo Security  Cloud Security, Cyber Security, Enterprise Sof...
# 6        ForgeRock  Cyber Security, Enterprise Software, Identity ...
# 7     Threat Stack                     Cloud Security, SaaS, Security
#
#                                    Location  \
# 0  Somerville, Massachusetts, United States
# 3             Bucharest, Bucuresti, Romania
# 4        Ann Arbor, Michigan, United States
# 6  San Francisco, California, United States
# 7      Boston, Massachusetts, United States
#
#                                            Region   ExitDate FundingDate  \
# 0    Greater Boston Area, East Coast, New England 2019-05-30  2017-10-31
# 3                             European Union (EU)        NaT  2017-12-01
# ...

# %%
tags = all_data.Place.apply(pd.Series)
tags = tags.rename(columns = lambda x : 'region_' + str(x+1))
tags.head(5)
# Out:
#                  region_1        region_2      region_3
# 0     Greater Boston Area      East Coast   New England
# 3     European Union (EU)             NaN           NaN
# 4             Great Lakes   Midwestern US           NaN
# 6  San Francisco Bay Area      West Coast    Western US
# 7     Greater Boston Area      East Coast   New England

# %%
my_data = pd.concat([all_data[:], tags[:]], axis=1)
all_data = my_data
all_data.shape
# Out:
# (2212, 25)

# %%
all_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2212 entries, 0 to 690
# Data columns (total 25 columns):
# Organization     2212 non-null object
# Categories       2212 non-null object
# Location         2175 non-null object
# Region           1841 non-null object
# ExitDate         73 non-null datetime64[ns]
# FundingDate      2212 non-null datetime64[ns]
# FundingAmount    2212 non-null float64
# FundingType      2212 non-null object
# EquityAmount     2108 non-null float64
# Status           1596 non-null object
# Top5             1702 non-null object
# Investors        1702 non-null float64
# Founded          1998 non-null float64
# Period           2212 non-null period[M]
# Quarter          2212 non-null object
# Invest           1702 non-null object
# investor_1       1702 non-null object
# investor_2       1194 non-null object
# investor_3       949 non-null object
# investor_4       737 non-null object
# investor_5       592 non-null object
# ...

# %%
all_data = all_data.drop(['Region', 'FundingDate', Top5','Invest','Place'], axis=1)
all_data.head(5)
# Out:
#       Organization                                         Categories  \
# 0  Recorded Future  Analytics, Cyber Security, Machine Learning, R...
# 3      Bitdefender  Cloud Security, Cyber Security, Network Securi...
# 4     Duo Security  Cloud Security, Cyber Security, Enterprise Sof...
# 6        ForgeRock  Cyber Security, Enterprise Software, Identity ...
# 7     Threat Stack                     Cloud Security, SaaS, Security
#
#                                    Location  FundingAmount       FundingType  \
# 0  Somerville, Massachusetts, United States     25000000.0          Series E
# 3             Bucharest, Bucuresti, Romania    180000000.0  Secondary Market
# 4        Ann Arbor, Michigan, United States     70000000.0          Series D
# 6  San Francisco, California, United States     88000000.0          Series D
# 7      Boston, Massachusetts, United States     45000000.0          Series C
#
#    EquityAmount              Status  Investors  Founded   Period Quarter  \
# ...

# %%
all_data.isnull().sum()
# Out:
# Organization        0
# Categories          0
# Location           37
# FundingAmount       0
# FundingType         0
# EquityAmount      104
# Status            616
# Investors         510
# Founded           214
# Period              0
# Quarter             0
# investor_1        510
# investor_2       1018
# investor_3       1263
# investor_4       1475
# investor_5       1620
# region_1          371
# region_2         1106
# region_3         1294
# dtype: int64

# %% [markdown]
# Write to CSV for backup

# %%
all_data.to_csv('investment-complete.csv', index=0)
